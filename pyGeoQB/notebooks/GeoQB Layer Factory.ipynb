# %% [markdown]
# # GeoQB Layer Factory
#
# We load data for a given position from the public OverPass API and create a set of Layers with POIs which will then be used for a personal acceptance potential analysis.

# %% [markdown]
# ![image.png](attachment:image.png)
